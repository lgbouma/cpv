# %%
import lightkurve as lk
import numpy as np, matplotlib.pyplot as plt
# %matplotlib inline

# %%
r = lk.search_lightcurve("TIC 59129133")
search_result = lk.search_targetpixelfile("TIC 59129133")
print(r)
print(search_result)
lc0 = r[5].download()
tpf0 = search_result[1].download()
lc1 = r[6].download()
tpf1 = search_result[2].download()
# Out:
# SearchResult containing 7 data products.
#
#  #     mission     year  author exptime  target_name  distance
#                                    s                   arcsec
# --- -------------- ---- ------- ------- ------------- --------
#   0 K2 Campaign 13 2017      K2    1800 ktwo246676629      0.0
#   1 K2 Campaign 13 2017 EVEREST    1800 ktwo246676629      0.0
#   2 K2 Campaign 13 2017   K2SFF    1800 ktwo246676629      0.0
#   3 TESS Sector 05 2018     QLP    1800      59129133      0.0
#   4 TESS Sector 32 2020     QLP     600      59129133      0.0
#   5 TESS Sector 43 2021    SPOC     120      59129133      0.0
#   6 TESS Sector 44 2021    SPOC     120      59129133      0.0
# SearchResult containing 3 data products.
#
#  #     mission     year author exptime  target_name  distance
#                                   s                   arcsec
# --- -------------- ---- ------ ------- ------------- --------
#   0 K2 Campaign 13 2017     K2    1800 ktwo246676629      0.0
#   1 TESS Sector 43 2021   SPOC     120      59129133      0.0
#   2 TESS Sector 44 2021   SPOC     120      59129133      0.0

# %%
time = np.array(lc0.time.value)
flux = np.array(lc0.pdcsap_flux.value)
plt.figure(figsize=(15,7))
plt.scatter(time, flux, s=1);

# %%
tpf0.interact()
# Out:
# <script id="1001">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:50891/autoload.js?bokeh-autoload-element=1001&bokeh-absolute-url=http://localhost:50891&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>

# %%
time = np.array(lc1.time.value)
flux = np.array(lc1.pdcsap_flux.value)
plt.figure(figsize=(15,7))
plt.scatter(time, flux, s=1);

# %%
tpf1.interact()
# Out:
# <script id="1002">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:50893/autoload.js?bokeh-autoload-element=1002&bokeh-absolute-url=http://localhost:50893&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>
